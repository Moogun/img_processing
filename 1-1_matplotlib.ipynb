# %%
import matplotlib.pyplot as plt
import numpy as np

# Some example data to display
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

# %%
fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(x, y)
axs[0, 0].set_title('Axis [0, 0]')
axs[0, 1].plot(x, y, 'tab:orange')
axs[0, 1].set_title('Axis [0, 1]')
axs[1, 0].plot(x, -y, 'tab:green')
axs[1, 0].set_title('Axis [1, 0]')
axs[1, 1].plot(x, -y, 'tab:red')
axs[1, 1].set_title('Axis [1, 1]')
# Out:
# Text(0.5, 1.0, 'Axis [1, 1]')

# %%
fig, axs = plt.subplots(3, 3, figsize=(20,10))
fig.suptitle('something')
for a in range(3):
    for b in range(3):
        axs[a, b].plot(x,y)
        axs[a, b].set_title('Axis [' + str(a) +',' + str(b) + ']')

# %%
tn = plt.imread('tn1.png')

# %%
fig, axs = plt.subplots(3, 3, figsize=(20,10))
fig.suptitle('something')
for a in range(3):
    for b in range(3):
        axs[a, b].imshow(tn)
        axs[a, b].set_title('Axis [' + str(a) +',' + str(b) + ']')

# %%
arr = [ [cv2.imread('tn2.png'), cv2.imread('tn2.png')], [cv2.imread('tn2.png'), cv2.imread('tn2.png')]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-0c0843f8f6fc> in <module>
# ----> 1 arr = [ [cv2.imread('tn2.png'), cv2.imread('tn2.png')], [cv2.imread('tn2.png'), cv2.imread('tn2.png')]]
#
# NameError: name 'cv2' is not defined

# %%
def plot(rows, cols, figsize, title, images):
    fig, axs = plt.subplots(rows, cols, figsize=figsize)
    fig.suptitle('something')
    for a in range(rows):
        for b in range(cols):
            axs[a, b].imshow(images[a][b])
            axs[a, b].set_title('Axis [' + str(a) +',' + str(b) + ']')
