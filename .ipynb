# %% [markdown]
# 1. git init
#
# 2. open up an image
# 3. extract channels ??
# 4. convert it into gray
#
# 5. dilate + erosion
# 6. thresholding
#
# 7. perspective transformation
# 8. then what ....
#
#
#
# 9. working with video
# 10. skipping frames
#
#
# # perspective correction, color collection

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy

# %%
tn1 = 'tn1.png'
plt.imshow(plt.imread(tn1))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-b524329b357b> in <module>
#       1 tn1 = 'tn1.png'
# ----> 2 plt.imshow(plt.imread(tn1))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in imread(fname, format)
#    2244 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2245 def imread(fname, format=None):
# -> 2246     return matplotlib.image.imread(fname, format)
#    2247
#    2248
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in imread(fname, format)
#    1494                     response = io.BytesIO(response.read())
#    1495                 return imread(response, format=ext)
# -> 1496     with img_open(fname) as image:
#    1497         return (_pil_png_to_float_array(image)
#    1498                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ...
