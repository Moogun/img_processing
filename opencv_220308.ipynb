# %% [markdown]
# <a href="https://colab.research.google.com/github/Moogun/img_processing/blob/master/opencv_220308.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import tensorflow as tf 
import cv2

# %%
np.arange(1, 11)

# %%
import cv2 #opencv itself
# import common #some useful opencv functions
import numpy as np # matrix manipulations

#the following are to do with this interactive notebook code
# %matplotlib inline 
from matplotlib import pyplot as plt # this lets you draw inline pictures in the notebooks
import pylab # this allows you to control figure size 
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # this controls figure size in the notebook

# %%
input_image=cv2.imread('1.JPG')
plt.imshow(input_image)

# %%
from IPython.display import HTML
from base64 import b64encode

# %%
mp4 = open('10mb.MOV','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %%
#@title check gpu
# !nvidia-smi

# %%
from google.colab.patches import cv2_imshow

# %%
cap = cv2.VideoCapture('10mb.MOV')
fourcc = cv2.VideoWriter_fourcc(*'XVID')

# VideoWriter is not working, but don't know why 
# out = cv2.VideoWriter('output.MOV', fourcc, 5, (100, 100))

while True:
  ret, frame = cap.read()
  if ret == True:
    # ---- RESIZE 
    # b = cv2.resize(frame, (100, 100), fx=0, fy=0, interpolation = cv2.INTER_CUBIC)
    # b = cv2.resize(frame, (100, 100))
    # out.write(b)

    # ---- CROPPING 
    # print("dimension", frame.shape)
    # cv2_imshow(frame[0:100, 0:100])

    # ---- VIDEO WRITER NOT WORKING 
    # b = frame[0:100, 0:100]
    # out.write(b)
  else:
    break

cap.release()
out.release()

# %%
mp4 = open('10mb.MOV','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %%
# below code is not tested
def video_to_mp4(input, output, fps: int = 0, frame_size: tuple = (), fourcc: str = "H264"):
    vidcap = cv2.VideoCapture(input)
    if not fps:
        fps = round(vidcap.get(cv2.CAP_PROP_FPS))
    success, arr = vidcap.read()
    if not frame_size:
        height, width, _ = arr.shape
        frame_size = width, height
    writer = cv2.VideoWriter(
        output,
        apiPreference=0,
        fourcc=cv2.VideoWriter_fourcc(*fourcc),
        fps=fps,
        frameSize=frame_size
    )
    while True:
        if not success:
            break
        writer.write(arr)
        success, arr = vidcap.read()
    writer.release()
    vidcap.release()

# %%
video_to_mp4('10mb.MOV', output="out.mov")
